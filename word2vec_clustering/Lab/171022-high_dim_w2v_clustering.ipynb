# %% [markdown]
# # Relation Word Clustering

# %% [markdown]
# ## Lab 1. for Full Corpus

# %%
import os, sys
sys.path.append(os.path.split(os.getcwd())[0])

from WordVector import WordVector

# %%
import data_helper
_,_,relation = data_helper.get_triplet()
relation[:5]
# Out:
# ['cause', 'cause', 'cause', 'cause', 'cause']

# %%
relation = list(set(relation))
relation[:5]
# Out:
# ['pathogen', 'agent', 'trigger', 'responsible', 'amount']

# %%
wv = WordVector(relation)
# Out:
# Loading a pre-trained model...
# Load success!

# %%
wv.word[:5]
# Out:
# ['pathogen', 'agent', 'trigger', 'responsible', 'amount']

# %%
wv.vector[0]
# Out:
# array([-2.88253355, -1.39683485, -1.16817617, -1.55536187, -0.21801218,
#         1.96350372, -2.43437243,  3.01821017,  4.34709501,  1.03212285,
#        -2.15543842, -1.87326872,  3.44667482, -0.82241231,  0.01196951,
#         1.62816381,  0.56441104,  0.50302958, -0.51895142,  0.02487616,
#         1.65582168,  1.84801054,  2.14449096,  5.12209654,  1.89816904,
#         0.04615263, -0.43411037,  0.31758189, -5.01787853, -0.47095498,
#         2.33863449,  1.78954458, -0.2785027 , -1.85647142,  1.93267441,
#        -1.12104213, -4.18306446,  0.78608006, -3.0814805 ,  3.55231452,
#         1.60787582, -5.54868984, -0.22725798,  1.61969125,  3.75358009,
#         1.65087473, -1.18255627,  0.07785696,  0.52234387,  0.67333865,
#         0.19982284,  0.34466365, -2.75742412,  0.70245945, -5.70976305,
#         4.90373182,  0.84766287, -1.48785973, -0.37021229, -2.55799913,
#        -5.63738871, -1.87357712, -1.69691515, -1.77152324,  0.73682451,
#         0.17478295, -1.58945334, -2.43884158, -0.39552811,  1.75991607,
#        -1.95013845,  0.85516083,  2.08372498, -0.01500638, -2.18609214,
#        -0.15702212,  3.41192722, -0.8932476 ,  1.44427288, -3.49372602,
#        -0.08578952, -3.4339478 , -1.88967657, -2.23841453, -2.90978861,
#        -0.50768924, -2.10562396,  1.93068659,  0.67263889, -3.24223185,
#         1.97217369, -3.99274111,  0.97000235, -2.00138497,  3.7932694 ,
#         1.28775537, -0.42045367, -0.6590699 ,  3.02757859,  1.19839752], dtype=float32)

# %% [markdown]
# ### 1-1) K = 3 Clustering

# %%
from sklearn.cluster import DBSCAN

# %%
k_means = cluster.KMeans(n_clusters=3)
k_means.fit(wv.vector)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([2, 2, 0, 0, 2], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(131)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(132)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(133)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

# %% [markdown]
# ### 1-2) K = 5 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(wv.vector)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([4, 4, 0, 0, 2], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(151)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(152)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(153)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

ax4 = fig.add_subplot(154)
ax4.set_title('Cluster #3', fontsize=18, fontweight='bold')
ax4.axis('off')
ax4.table(cellText = df[df.Cluster == 3].values, bbox=bbox).set_fontsize(24)

ax5 = fig.add_subplot(155)
ax5.set_title('Cluster #4', fontsize=18, fontweight='bold')
ax5.axis('off')
ax5.table(cellText = df[df.Cluster == 4].values, bbox=bbox).set_fontsize(24)

# %% [markdown]
# ### 1-3) K = 10 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=10)
k_means.fit(wv.vector)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([3, 2, 9, 0, 4], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,30))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(251)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(252)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(253)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

ax4 = fig.add_subplot(254)
ax4.set_title('Cluster #3', fontsize=18, fontweight='bold')
ax4.axis('off')
ax4.table(cellText = df[df.Cluster == 3].values, bbox=bbox).set_fontsize(24)

ax5 = fig.add_subplot(255)
ax5.set_title('Cluster #4', fontsize=18, fontweight='bold')
ax5.axis('off')
ax5.table(cellText = df[df.Cluster == 4].values, bbox=bbox).set_fontsize(24)

ax6 = fig.add_subplot(256)
ax6.set_title('Cluster #5', fontsize=18, fontweight='bold')
ax6.axis('off')
ax6.table(cellText = df[df.Cluster == 5].values, bbox=bbox).set_fontsize(24)

ax7 = fig.add_subplot(257)
ax7.set_title('Cluster #6', fontsize=18, fontweight='bold')
ax7.axis('off')
ax7.table(cellText = df[df.Cluster == 6].values, bbox=bbox).set_fontsize(24)

ax8 = fig.add_subplot(258)
ax8.set_title('Cluster #7', fontsize=18, fontweight='bold')
ax8.axis('off')
ax8.table(cellText = df[df.Cluster == 7].values, bbox=bbox).set_fontsize(24)

ax9 = fig.add_subplot(259)
ax9.set_title('Cluster #8', fontsize=18, fontweight='bold')
ax9.axis('off')
ax9.table(cellText = df[df.Cluster == 8].values, bbox=bbox).set_fontsize(24)

ax10 = fig.add_subplot(2,5,10)
ax10.set_title('Cluster #9', fontsize=18, fontweight='bold')
ax10.axis('off')
ax10.table(cellText = df[df.Cluster == 9].values, bbox=bbox).set_fontsize(24)
