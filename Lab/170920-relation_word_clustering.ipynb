# %% [markdown]
# # Relation Word Clustering

# %% [markdown]
# ## Lab 1. for Full Corpus

# %%
import os, sys
sys.path.append(os.path.split(os.getcwd())[0])

from word2vec_module import *

# %%
module = word2vec_module('full')
# Out:
# Loading a pre-trained model...
# Load success!

# %%
_, _, relation = module.get_key_word()

# %%
relation = list(set(relation))
relation[:5]
# Out:
# ['accompany', 'evaluate', 'infusion', 'associate', 'trigger']

# %%
relation.remove('eon')
relation.remove('under-represent')
rel_vec = module.model[relation]

# %%
rel_vec[:5]
# Out:
# array([[-0.0776362 ,  3.45275593,  0.87835318],
#        [ 1.77736926,  4.62702036, -1.31076622],
#        [-4.47828531,  2.7232008 , -0.02525542],
#        [ 0.01244094,  5.63088846,  3.93214202],
#        [ 1.17402375,  4.02282047,  0.08704425]], dtype=float32)

# %% [markdown]
# ### 1-1) K = 3 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=3)
k_means.fit(rel_vec)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([1, 2, 1, 0, 2], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(131)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(132)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(133)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

# %% [markdown]
# ### 1-2) K = 5 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(rel_vec)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([1, 1, 0, 3, 1], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(151)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(152)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(153)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

ax4 = fig.add_subplot(154)
ax4.set_title('Cluster #3', fontsize=18, fontweight='bold')
ax4.axis('off')
ax4.table(cellText = df[df.Cluster == 3].values, bbox=bbox).set_fontsize(24)

ax5 = fig.add_subplot(155)
ax5.set_title('Cluster #4', fontsize=18, fontweight='bold')
ax5.axis('off')
ax5.table(cellText = df[df.Cluster == 4].values, bbox=bbox).set_fontsize(24)

# %% [markdown]
# ## Lab 2. for Relation Corpus

# %%
module = word2vec_module('relation')
# Out:
# Loading a pre-trained model...
# Load success!

# %%
_, _, relation = module.get_key_word()

# %%
relation = list(set(relation))
relation[:5]
# Out:
# ['accompany', 'evaluate', 'infusion', 'associate', 'trigger']

# %%
relation.remove('eon')
relation.remove('under-represent')
relation.remove('premature')

rel_vec = module.model[relation]

# %%
rel_vec[:5]
# Out:
# array([[-0.02220456, -0.13997737,  0.08793989],
#        [-0.15784276,  0.28544348,  0.06201895],
#        [-0.18572214, -0.04537086,  0.05502172],
#        [-0.21321981,  0.12175536, -0.12310008],
#        [-0.01859221, -0.06580278,  0.14027368]], dtype=float32)

# %% [markdown]
# ### 2-1) K = 3 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=3)
k_means.fit(rel_vec)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(131)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(132)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(133)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

# %% [markdown]
# ### 2-2) K = 5 Clustering

# %%
from sklearn import cluster

# %%
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(rel_vec)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
label = k_means.labels_
label[:5]
# Out:
# array([3, 1, 3, 1, 3], dtype=int32)

# %% [markdown]
# ### Result

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['Relation', 'Cluster'])
df['Relation'] = relation
df['Cluster'] = label

# %%
df.sort_values(['Relation'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18,15))
bbox = [0,0,1,1]

ax1 = fig.add_subplot(151)
ax1.set_title('Cluster #0', fontsize=18, fontweight='bold')
ax1.axis('off')
ax1.table(cellText = df[df.Cluster == 0].values, bbox=bbox).set_fontsize(24)

ax2 = fig.add_subplot(152)
ax2.set_title('Cluster #1', fontsize=18, fontweight='bold')
ax2.axis('off')
ax2.table(cellText = df[df.Cluster == 1].values, bbox=bbox).set_fontsize(24)

ax3 = fig.add_subplot(153)
ax3.set_title('Cluster #2', fontsize=18, fontweight='bold')
ax3.axis('off')
ax3.table(cellText = df[df.Cluster == 2].values, bbox=bbox).set_fontsize(24)

ax4 = fig.add_subplot(154)
ax4.set_title('Cluster #3', fontsize=18, fontweight='bold')
ax4.axis('off')
ax4.table(cellText = df[df.Cluster == 3].values, bbox=bbox).set_fontsize(24)

ax5 = fig.add_subplot(155)
ax5.set_title('Cluster #4', fontsize=18, fontweight='bold')
ax5.axis('off')
ax5.table(cellText = df[df.Cluster == 4].values, bbox=bbox).set_fontsize(24)
