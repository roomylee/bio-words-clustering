# %% [markdown]
# # Triplet(BAC-REL-DIS) Visualization(3-dim)
# ## 171027
# * baseline code
#
# ## 171115 update
# * Only connected edge BAC-REL and REL-DIS
# * use vector value generated by word2vec

# %%
import os, sys
sys.path.append(os.path.split(os.getcwd())[0])

from WordVector import WordVector
from DimensionReduction import DimensionReduction
import pandas as pd

# %%
import data_helper
bac,dis,rel = data_helper.get_triplet()
bac.sort()
dis.sort()
rel.sort()
nodes = bac + dis + rel
print("Bacteria List({0}): {1}".format(len(bac), bac[:5]))
print("Disease List({0}): {1}".format(len(dis), dis[:5]))
print("Relation List({0}): {1}".format(len(rel), rel[:5]))
# Out:
# Bacteria List(276): ['BAC00actinmey', 'BAC00actinne', 'BAC00aerohydro', 'BAC00bacianth', 'BAC00bacianth']
# Disease List(276): ['DIS00actinomycosis', 'DIS00actinomycosis', 'DIS00bactpneu', 'DIS00bactpneu', 'DIS00diarrhea']
# Relation List(276): ['abdominal', 'accompany', 'acquire', 'agent', 'agent']

# %% [markdown]
# #### nodes : Bacteria + Disease + Relation words

# %%
print("All Nodes({0}): {1}".format(len(nodes), nodes[:5]))
# Out:
# All Nodes(828): ['BAC00actinmey', 'BAC00actinne', 'BAC00aerohydro', 'BAC00bacianth', 'BAC00bacianth']

# %% [markdown]
# #### unique nodes

# %%
unique_nodes = list(set(nodes))
unique_nodes.sort()

# %%
print("Unique Nodes({0}): {1}".format(len(unique_nodes), unique_nodes[:5]))
# Out:
# Unique Nodes(141): ['BAC00actinmey', 'BAC00actinne', 'BAC00aerohydro', 'BAC00bacianth', 'BAC00bifidobbif']

# %% [markdown]
# #### word2vec

# %%
wv = WordVector(unique_nodes, dim=10)
# Out:
# Loading a pre-trained model...
# Load success!

# %%
vec_3dim = DimensionReduction().PCA(vector=wv.vector, dim=3)
# Out:
# Explained variation per principal component: [ 0.25880969  0.19610742  0.14437555]
# Average of Explained variations: 0.5992926359176636

# %%
df = pd.DataFrame()
df['words'] = wv.word
df['x'] = [v[0] for v in wv.vector]
df['y'] = [v[1] for v in wv.vector] 
df['z'] = [v[2] for v in wv.vector]

# %%
group = []
for w in wv.word:
    if w[:3] == "BAC":
        group.append(1)
    elif w[:3] == "DIS":
        group.append(2)
    else:
        group.append(3)
df['group'] = group

# %%
df['index'] = df.index

# %%
df = df[['index','words','x','y','z', 'group']]

# %%
df.head()
# Out:
#    index            words         x         y         z  group
# 0      0    BAC00actinmey  0.225603 -0.212015 -0.203851      1
# 1      1     BAC00actinne  0.382572 -0.149741 -0.001161      1
# 2      2   BAC00aerohydro  1.366007 -0.150797 -0.088442      1
# 3      3    BAC00bacianth  1.158517 -0.055536 -0.320448      1
# 4      4  BAC00bifidobbif  0.405588 -0.030100 -0.065202      1

# %% [markdown]
# ### Numbering to Entities

# %%
nodes_num = {}
for i in range(len(unique_nodes)):
    nodes_num[unique_nodes[i]] = i

# %%
nodes_num
# Out:
# {'BAC00actinmey': 0,
#  'BAC00actinne': 1,
#  'BAC00aerohydro': 2,
#  'BAC00bacianth': 3,
#  'BAC00bifidobbif': 4,
#  'BAC00bifidoblon': 5,
#  'BAC00burkhocenoc': 6,
#  'BAC00burkhocep': 7,
#  'BAC00burkhomal': 8,
#  'BAC00burkhopseudo': 9,
#  'BAC00campyljej': 10,
#  'BAC00citrokos': 11,
#  'BAC00citrorode': 12,
#  'BAC00clostperfr': 13,
#  'BAC00corynebamyco': 14,
#  'BAC00corynebjeik': 15,
#  'BAC00corynebxer': 16,
#  'BAC00empedobre': 17,
#  'BAC00enteroaero': 18,
#  'BAC00enteroclo': 19,
#  'BAC00enterofaec': 20,
#  'BAC00erysiperhusio': 21,
#  'BAC00escheco': 22,
#  'BAC00fusobanecro': 23,
#  'BAC00haemoinflu': 24,
#  'BAC00klebspneum': 25,
#  'BAC00lactobplan': 26,
#  'BAC00lactoplan': 27,
#  'BAC00listmonocy': 28,
#  'BAC00neismening': 29,
#  'BAC00pandisp': 30,
#  'BAC00prevobuc': 31,
#  'BAC00promira': 32,
#  'BAC00pseudaerug': 33,
#  'BAC00raoulornithi': 34,
#  'BAC00salmoente': 35,
#  'BAC00sebaltermi': 36,
#  'BAC00staphylaur': 37,
#  'BAC00staphylcarn': 38,
#  'BAC00staphylepide': 39,
#  'BAC00stenotromalto': 40,
#  'BAC00streptagala': 41,
#  'BAC00streptaur': 42,
#  'BAC00streptgallol': 43,
#  'BAC00streptmi': 44,
#  'BAC00streptpneum': 45,
#  'BAC00streptpyog': 46,
#  'BAC00streptsu': 47,
#  'BAC00ureapureal': 48,
#  'BAC00vibvulni': 49,
#  'BAC00wohlfahrchitini': 50,
#  'BAC00yersenteroc': 51,
#  'BAC00yerspes': 52,
#  'DIS00actinomycosis': 53,
#  'DIS00bactpneu': 54,
#  'DIS00diarrhea': 55,
#  'DIS00disease': 56,
#  'DIS00diseases': 57,
#  'DIS00gastrointestinal': 58,
#  'DIS00glanders': 59,
#  'DIS00influenzae': 60,
#  'DIS00melioidosis': 61,
#  'DIS00meningitis': 62,
#  'DIS00plague': 63,
#  'DIS00pneumonia': 64,
#  'DIS00pneumoniae': 65,
#  'DIS00sepsis': 66,
#  'DIS00sepsis-induced': 67,
#  'DIS00sepsis/DIS00meningitis': 68,
#  'abdominal': 69,
#  'accompany': 70,
#  'acquire': 71,
#  'agent': 72,
#  'airway': 73,
#  'amount': 74,
#  'appear': 75,
#  'ascribe': 76,
#  'associate': 77,
#  'bacterium': 78,
#  'capacity': 79,
#  'catheter-relate': 80,
#  'cause': 81,
#  'challenge': 82,
#  'colonise': 83,
#  'colonize': 84,
#  'constitute': 85,
#  'consumption': 86,
#  'contaminate': 87,
#  'due': 88,
#  'during': 89,
#  'early-onset': 90,
#  'effective': 91,
#  'episode': 92,
#  'etiology': 93,
#  'evaluate': 94,
#  'evoke': 95,
#  'experimental': 96,
#  'factor': 97,
#  'follow': 98,
#  'gram-negative': 99,
#  'incidence': 100,
#  'induce': 101,
#  'infection': 102,
#  'inflammation': 103,
#  'infusion': 104,
#  'initiate': 105,
#  'inject': 106,
#  'injection': 107,
#  'isolate': 108,
#  'lead': 109,
#  'manifestation': 110,
#  'model': 111,
#  'mortality': 112,
#  'mouse': 113,
#  'neonatal': 114,
#  'obtain': 115,
#  'organism': 116,
#  'overwhelm': 117,
#  'oyster': 118,
#  'pathogen': 119,
#  'patient': 120,
#  'phenotype': 121,
#  'predominate': 122,
#  'premature': 123,
#  'prevent': 124,
#  'produce': 125,
#  'protect': 126,
#  'recover': 127,
#  'reduce': 128,
#  'responsible': 129,
#  'result': 130,
#  'survival': 131,
#  'syndrome': 132,
#  'systemic': 133,
#  'tool': 134,
#  'tract': 135,
#  'translocation': 136,
#  'traverse': 137,
#  'trigger': 138,
#  'type': 139,
#  'use': 140}

# %% [markdown]
# ### make Edges based on numbering value

# %%
Edges = []
for i in range(len(bac)):
    Edges.append((nodes_num[bac[i]], nodes_num[rel[i]]))
    Edges.append((nodes_num[rel[i]], nodes_num[dis[i]]))

print("Edges List({0}): {1}".format(len(Edges),Edges[:5]))
# Out:
# Edges List(552): [(0, 69), (69, 53), (1, 70), (70, 53), (2, 71)]

# %%
Xe=[]
Ye=[]
Ze=[]
for e in Edges:
    Xe+=[df.loc[e[0]].x,df.loc[e[1]].x, None]# x-coordinates of edge ends
    Ye+=[df.loc[e[0]].y,df.loc[e[1]].y, None]
    Ze+=[df.loc[e[0]].z,df.loc[e[1]].z, None]

# %% [markdown]
# ## 3D Visualization using plotly

# %%
import plotly.plotly as py
from plotly.graph_objs import *

# %%
# Edge Viz
trace1=Scatter3d(x=Xe,
                 y=Ye,
                 z=Ze,
                 mode='lines',
                 line=Line(color='rgb(125,125,125)', width=1),
                 hoverinfo='none'
                )
# Nodes Viz
trace2=Scatter3d(x=df['x'],
                 y=df['y'],
                 z=df['z'],
                 mode='markers',
                 name='actors',
                 marker=Marker(symbol='dot',
                               size=4,
                               color=df['group'],
                               colorscale='Viridis',
                               line=Line(color='rgb(50,50,50)', width=0.5)
                              ),
                 text=df['words'],
                 hoverinfo='text'
                )

# %%
axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

# %%
layout = Layout(
         title="Bio Triplet Visualization",
         width=1000,
         height=1000,
         showlegend=False,
         scene=Scene(
         xaxis=XAxis(axis),
         yaxis=YAxis(axis),
         zaxis=ZAxis(axis),
        ),
     margin=Margin(
        t=100
    ),
    hovermode='closest',
    annotations=Annotations([
           Annotation(
           showarrow=False,
            text="",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=Font(
            size=14
            )
            )
        ]),    )

# %%
data_=Data([trace1, trace2])
fig=Figure(data=data_, layout=layout)

py.iplot(fig, filename='Bio Triplet Visualization')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~JooHongLee/244.embed" height="1000px" width="1000px"></iframe>
